# %% [markdown]
# # CHARACTHER SHEET

# %% [markdown]
# ## Example Below

# %%
import json
from src.api.base import *


# 7. Correct Instantiation Syntax
char = CharacterData(
    character_identity=CharacterIdentity(
        names=NameSection(full_name="test", nicknames=["test"])
    )
)

# Test verification
print(char.model_dump_json(indent=2))
# Out:
# {
#   "id": "",
#   "character_identity": {
#     "names": {
#       "full_name": "test",
#       "nicknames": [
#         "test"
#       ]
#     },
#     "gender_and_sex": {
#       "gender": null,
#       "sexuality": null
#     },
#     "occupational": {
#       "occupation": "",
#       "job_satisfaction": 3,
#       "in_depth": ""
#     }
#   }
# }
